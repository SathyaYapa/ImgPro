# %% [markdown]
# #D/ENG/21/0109

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

y, x= np.arange(-1, 2, 1), np.arange(-1, 2, 1)
YY, XX= np.meshgrid(x,y)
sigma = 1.
g= np.exp(-(XX**2+YY**2)/(2*sigma**2))
g/=np.sum(100*g)


im= cv.imread(r"D:\Saves\Python\ImgPro\images\lakshan.jpg", cv.IMREAD_REDUCED_GRAYSCALE_2)
assert im is not None

blurred= cv.filter2D(im, -1, g)

fig, ax= plt.subplots(1,2, figsize=(12,24))
ax[0].imshow(im, cmap='gray')
ax[0].set_title('Original')
ax[1].imshow(blurred, cmap='gray')
ax[1].set_title('Blurred')
# Out:
# Text(0.5, 1.0, 'Blurred')

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

im= cv.imread(r"D:\Saves\Python\ImgPro\images\girl.jpg", cv.IMREAD_REDUCED_GRAYSCALE_2)
assert im is not None

edges= cv.Canny( im, 200, 50)

fig, ax= plt.subplots(1,2, figsize=(12,24))
ax[0].imshow(im, cmap='gray')
ax[0].set_title('Original')
ax[1].imshow(edges, cmap='gray')
ax[1].set_title('Canny edge detected')
# Out:
# Text(0.5, 1.0, 'Blurred')
