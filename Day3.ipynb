# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

im = cv.imread(r"D:\Saves\Python\ImgPro\images\BrainProtonDensitySliceBorder.png", cv.IMREAD_GRAYSCALE)
assert im is not None


t = np.arange(0,256).astype(np.uint8)

t[0:99]=0
t[201:255]=0
plt.plot(t)

g = t[im]

#plt.imshow(g)
#plt.show()




'''
cv.namedWindow('image', cv.WINDOW_KEEPRATIO)

cv.imshow('image', im)
cv.waitKey(0)
cv.imshow('image', g)
cv.waitKey(0)

cv.destroyAllWindows()
'''
# Out:
# "\ncv.namedWindow('image', cv.WINDOW_KEEPRATIO)\n\ncv.imshow('image', im)\ncv.waitKey(0)\ncv.imshow('image', g)\ncv.waitKey(0)\n\ncv.destroyAllWindows()\n"

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

im = cv.imread(r"D:\Saves\Python\ImgPro\images\PXL.jpg", cv.IMREAD_GRAYSCALE)
assert im is not None

gamma=0.1
t= np.array([(i/255.)**gamma*255 for i in range(256)], dtype=np.uint8)

g = t[im]
print(im.shape)
#plt.plot(t)

plt.subplot(1,2,1)
plt.imshow(im, cmap="gray", vmin=0, vmax=255)

plt.subplot(1,2,2)
plt.imshow(g, cmap="gray", vmin=0, vmax=255)


plt.show()



''''

cv.namedWindow('image', cv.WINDOW_KEEPRATIO)


cv.imshow('image', im)
cv.waitKey(0)
cv.imshow('image', g)
cv.waitKey(0)

cv.destroyAllWindows()

'''
# Out:
# (4032, 3024)
# "'\n\ncv.namedWindow('image', cv.WINDOW_KEEPRATIO)\n\n\ncv.imshow('image', im)\ncv.waitKey(0)\ncv.imshow('image', g)\ncv.waitKey(0)\n\ncv.destroyAllWindows()\n\n"

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

im = cv.imread(r"D:\Saves\Python\ImgPro\images\PXL.jpg", cv.IMREAD_GRAYSCALE)
assert im is not None

h = np.zeros(256)
u = [np.sum(im == i) for i in range(256)]

g = cv.equalizeHist(im)
h = [np.sum(g == i) for i in range(256)]


plt.subplot(1,2,1)
plt.subplot(range(256),im)

#plt.imshow(im, cmap="gray", vmin=0, vmax=255)

plt.subplot(1,2,2)
plt.plot(range(256),h)
#plt.imshow(h, cmap="gray", vmin=0, vmax=255)



#plt.bar(range(256), h)
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 16
#      12 h = [np.sum(g == i) for i in range(256)]
#      15 plt.subplot(1,2,1)
# ---> 16 plt.subplot(range(256),im)
#      18 #plt.imshow(im, cmap="gray", vmin=0, vmax=255)
#      20 plt.subplot(1,2,2)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\matplotlib\pyplot.py:1272, in subplot(*args, **kwargs)
#    1269 fig = gcf()
#    1271 # First, search for an existing subplot with a matching spec.
# -> 1272 key = SubplotSpec._from_subplot_args(fig, args)
#    1274 for ax in fig.axes:
#    1275     # if we found an Axes at the position sort out if we can re-use it
#    1276     if hasattr(ax, 'get_subplotspec') and ax.get_subplotspec() == key:
#    1277         # if the user passed no kwargs, re-use
#
# File ~\AppData\Roaming\Python\Python311\site-packages\matplotlib\gridspec.py:590, in SubplotSpec._from_subplot_args(figure, args)
#     588     rows, cols, num = args
#     589 else:
# --> 590     raise TypeError(f"subplot() takes 1 or 3 positional arguments but "
#     591                     f"{len(args)} were given")
#     593 gs = GridSpec._check_gridspec_exists(figure, rows, cols)
#     594 if gs is None:
#
# TypeError: subplot() takes 1 or 3 positional arguments but 2 were given
